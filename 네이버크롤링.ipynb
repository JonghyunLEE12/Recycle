# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as bs
import time
import re

driver = webdriver.Chrome('C:/Temp/chromedriver')
driver.get('https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EA%B9%A8%EC%A7%84%EC%9C%A0%EB%A6%AC%EB%B3%91')

# %%
for _ in range(8) :
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(0.5)

# %%
imgs=[]

start=1
end=550

for n in range(start,end+1):
    images=driver.find_elements_by_css_selector('#main_pack > section.sc_new.sp_nimage._prs_img._imageSearchPC > div > div.photo_group._listGrid > div.photo_tile._grid > div:nth-child('+str(n)+') > div > div.thumb > a > img')
    for doms in images:
        url = doms.get_attribute('src')
        imgs.append(url)

# %%
len(imgs)
# Out:
# 550

# %%
imgs
# Out:
# ['...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAxODA0MjBfNzEg%2FMDAxNTI0MjA0MzM5MjA5.nDzXPpeJp0RAeGXPPGOJJJ_IAIDxL-69IvgvzUj0Tjsg.Lf19_G_PTWYy97IAk9X5Lerv7wld0hOmUyTOWzHKbhMg.JPEG.pul_saem%2F11.jpg&type=a340',
#  'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMDA3MDlfMjA3%2FMDAxNTk0MjYwMjYyODQ4.HIZb39LUHcXqtCiMa0vHiXKinzVtWtRKETf-qOoMHuMg.tMxsdoyAXHVuyBT5CbiS001JPRFXdcRWJol_A0Ln0ssg.JPEG.mickyjung%2FIMG_7533.jpg&type=a340',
# ...

# %%
import os 
from urllib.request import urlretrieve

img_folder = './img'

if not os.path.isdir(img_folder) : # 없으면 새로 생성하는 조건문 
    os.mkdir(img_folder)
    
for index, link in enumerate(imgs) :
    time.sleep(0.5)
    urlretrieve(link, f'./img/{index}.jpg')

# %%
print(nonColorPet)
